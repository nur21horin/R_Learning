# %% [markdown]
# <a href="https://colab.research.google.com/github/nur21horin/R_Learning/blob/main/DS411_A2_Lab5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
df<-read.csv('/content/Iris (3).csv')

# %%
df
# Out:
#     Id  SepalLengthCm SepalWidthCm PetalLengthCm PetalWidthCm Species
# 1    1  5.1           3.5          1.4           0.2          Iris-setosa
# 2    2  4.9           3.0          1.4           0.2          Iris-setosa
# 3    3  4.7           3.2          1.3           0.2          Iris-setosa
# 4    4  4.6           3.1          1.5           0.2          Iris-setosa
# 5    5  5.0           3.6          1.4           0.2          Iris-setosa
# 6    6  5.4           3.9          1.7           0.4          Iris-setosa
# 7    7  4.6           3.4          1.4           0.3          Iris-setosa
# 8    8  5.0           3.4          1.5           0.2          Iris-setosa
# 9    9  4.4           2.9          1.4           0.2          Iris-setosa
# 10  10  4.9           3.1          1.5           0.1          Iris-setosa
# 11  11  5.4           3.7          1.5           0.2          Iris-setosa
# 12  12  4.8           3.4          1.6           0.2          Iris-setosa
# ...

# %%
mean(df$PetalLengthCm)
# Out:
# [1] 3.758667

# %%
median(df$PetalLengthCm)
# Out:
# [1] 4.35

# %%
sd(df$PetalLengthCm)
# Out:
# [1] 1.76442

# %%
var(df$PetalLengthCm)
# Out:
# [1] 3.113179

# %%
IQR(df$PetalLengthCm)
# Out:
# [1] 3.5

# %%
range(df$PetalLengthCm)
# Out:
# [1] 1.0 6.9

# %%
#NUY

# %%
quantile(df$PetalLengthCm,probs=c(0.25,0.5,0.75))
# Out:
#  25%  50%  75%
# 1.60 4.35 5.10

# %%
install.packages("e1071")
library(e1071)
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
skewness(df$PetalLengthCm)
# Out:
# [1] -0.2689994

# %%
kurtosis(df$PetalLengthCm)
# Out:
# [1] -1.416683

# %%
df
# Out:
#     Id  SepalLengthCm SepalWidthCm PetalLengthCm PetalWidthCm Species
# 1    1  5.1           3.5          1.4           0.2          Iris-setosa
# 2    2  4.9           3.0          1.4           0.2          Iris-setosa
# 3    3  4.7           3.2          1.3           0.2          Iris-setosa
# 4    4  4.6           3.1          1.5           0.2          Iris-setosa
# 5    5  5.0           3.6          1.4           0.2          Iris-setosa
# 6    6  5.4           3.9          1.7           0.4          Iris-setosa
# 7    7  4.6           3.4          1.4           0.3          Iris-setosa
# 8    8  5.0           3.4          1.5           0.2          Iris-setosa
# 9    9  4.4           2.9          1.4           0.2          Iris-setosa
# 10  10  4.9           3.1          1.5           0.1          Iris-setosa
# 11  11  5.4           3.7          1.5           0.2          Iris-setosa
# 12  12  4.8           3.4          1.6           0.2          Iris-setosa
# ...

# %%
library(tibble)
df1<-as_tibble(df[,2:5])

# %%
df1
# Out:
#     SepalLengthCm SepalWidthCm PetalLengthCm PetalWidthCm
# 1   5.1           3.5          1.4           0.2
# 2   4.9           3.0          1.4           0.2
# 3   4.7           3.2          1.3           0.2
# 4   4.6           3.1          1.5           0.2
# 5   5.0           3.6          1.4           0.2
# 6   5.4           3.9          1.7           0.4
# 7   4.6           3.4          1.4           0.3
# 8   5.0           3.4          1.5           0.2
# 9   4.4           2.9          1.4           0.2
# 10  4.9           3.1          1.5           0.1
# 11  5.4           3.7          1.5           0.2
# 12  4.8           3.4          1.6           0.2
# 13  4.8           3.0          1.4           0.1
# 14  4.3           3.0          1.1           0.1
# 15  5.8           4.0          1.2           0.2
# 16  5.7           4.4          1.5           0.4
# 17  5.4           3.9          1.3           0.4
# 18  5.1           3.5          1.4           0.3
# ...

# %%
cor(df1)
# Out:
#               SepalLengthCm SepalWidthCm PetalLengthCm PetalWidthCm
# SepalLengthCm  1.0000000    -0.1093692    0.8717542     0.8179536
# SepalWidthCm  -0.1093692     1.0000000   -0.4205161    -0.3565441
# PetalLengthCm  0.8717542    -0.4205161    1.0000000     0.9627571
# PetalWidthCm   0.8179536    -0.3565441    0.9627571     1.0000000

# %%
cor(df1,method="pearson")
# Out:
#               SepalLengthCm SepalWidthCm PetalLengthCm PetalWidthCm
# SepalLengthCm  1.0000000    -0.1093692    0.8717542     0.8179536
# SepalWidthCm  -0.1093692     1.0000000   -0.4205161    -0.3565441
# PetalLengthCm  0.8717542    -0.4205161    1.0000000     0.9627571
# PetalWidthCm   0.8179536    -0.3565441    0.9627571     1.0000000

# %%
cor(df1,method="spearman")
# Out:
#               SepalLengthCm SepalWidthCm PetalLengthCm PetalWidthCm
# SepalLengthCm  1.0000000    -0.1594565    0.8813864     0.8344207
# SepalWidthCm  -0.1594565     1.0000000   -0.3034206    -0.2775111
# PetalLengthCm  0.8813864    -0.3034206    1.0000000     0.9360034
# PetalWidthCm   0.8344207    -0.2775111    0.9360034     1.0000000

# %%
install.packages("reshape2")
install.packages("ggplot2")
library(ggplot2)
library(reshape2)
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependency ‘plyr’
#
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
#
# Attaching package: ‘ggplot2’
#
#
# The following object is masked from ‘package:e1071’:
#
#     element

# %%
cor_mat<-cor(df1)
melted<-melt(cor_mat)
ggplot(melted, aes(x = Var1, y = Var2, fill = value))+geom_tile() +geom_text(aes(label=round(value,3)),color="black")+scale_fill_gradient2(low="blue",high="red",mid="white",midpoint = 0)+theme_minimal()+labs(title="Correlation Heatmap")
# Out:
# plot without title

# %%
ggplot(df,aes(df$PetalLengthCm,fill=Species))+geom_density(alpha=0.4)+theme_minimal()
# Out:
# Warning message:
# “Use of `df$PetalLengthCm` is discouraged.
# ℹ Use `PetalLengthCm` instead.”
# plot without title
