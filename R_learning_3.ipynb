# %% [markdown]
# <a href="https://colab.research.google.com/github/nur21horin/R_Learning/blob/main/R_learning_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name<-29
cat(name*2)
# Out:
# 58

# %%
Age<-function(x,y){
  return (x+y);
}
age<-Age(4,5)
name<-readline(prompt("Enter your name: "))
cat("Hello ",name ,"Your age is",age)
# Out:
# Created file named ‘Enter your name: .Rd’.
# Edit the file and move it to the appropriate directory.
# Enter your name: .Rd2
# Hello  2 Your age is 9

# %%
age<-readline("Enter age: ")
cat(age,"/n")
# Out:
# Enter age: 2
# 2 /n

# %%
for(i in 1:5){
  cat("iteration number",i,"\n")
}
# Out:
# iteration number 1
# iteration number 2
# iteration number 3
# iteration number 4
# iteration number 5

# %%
fuits<-c("Apple","Banane","cherry")
for(fruit in fuits){
  cat(fruit," ")
}
# Out:
# Apple  Banane  cherry

# %%
count<-1

while(count<=3){
  cat("Current count: ",count)
  count<-count+1
}
# Out:
# Current count:  1Current count:  2Current count:  3

# %%
score<-readline("Enter your marks: ")

if(score>=90){
  cat("Grade : A")
}else if(score>=80){
  cat("Grade B")
}else{
  print("Need improvement porte bosh haramjada")
}
# Out:
# Enter your marks: 90
# Grade : A
