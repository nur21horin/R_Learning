# %% [markdown]
# <a href="https://colab.research.google.com/github/nur21horin/R_Learning/blob/main/Untitled15.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name<-29
cat(name*2)
# Out:
# 58

# %%
Age<-function(x,y){
  return (x+y);
}
age<-Age(4,5)
name<-readline(prompt("Enter your name: "))
cat("Hello ",name ,"Your age is",age)
# Out:
# Created file named ‘Enter your name: .Rd’.
# Edit the file and move it to the appropriate directory.
# Enter your name: .RdShafin
# Hello  Shafin Your age is 9
