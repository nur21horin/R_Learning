# %% [markdown]
# <a href="https://colab.research.google.com/github/nur21horin/R_Learning/blob/main/Untitled14.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
df<-read.csv("/content/Nuclear_Power_Plant_CPS_Dataset.csv")

# %%
df
# Out:
#      Timestamp           Reactor.Temp...C. Coolant.Flow.Rate..L.s.
# 1    2024-10-16 10:00:00 357.4507          471.8784
# 2    2024-10-16 10:01:00 347.9260          463.5589
# 3    2024-10-16 10:02:00 359.7153          471.8345
# 4    2024-10-16 10:03:00 372.8454          478.1495
# 5    2024-10-16 10:04:00 346.4877          470.7329
# 6    2024-10-16 10:05:00 346.4879          470.6089
# 7    2024-10-16 10:06:00 373.6882          459.4701
# 8    2024-10-16 10:07:00 361.5115          460.0565
# 9    2024-10-16 10:08:00 342.9579          448.9609
# 10   2024-10-16 10:09:00 358.1384          496.2437
# 11   2024-10-16 10:10:00 343.0487          451.3421
# 12   2024-10-16 10:11:00 343.0141          459.6064
# 13   2024-10-16 10:12:00 353.6294          459.2239
# 14   2024-10-16 10:13:00 321.3008          483.4239
# 15   2024-10-16 10:14:00 324.1262          465.5758
# 16   2024-10-16 10:15:00 341.5657          488.7161
# 17   2024-10-16 10:16:00 334.8075          459.8976
# ...

# %%
head(df)
# Out:
#   Timestamp           Reactor.Temp...C. Coolant.Flow.Rate..L.s. Pressure..MPa.
# 1 2024-10-16 10:00:00 357.4507          471.8784                15.63913
# 2 2024-10-16 10:01:00 347.9260          463.5589                16.08841
# 3 2024-10-16 10:02:00 359.7153          471.8345                15.72666
# 4 2024-10-16 10:03:00 372.8454          478.1495                15.86417
# 5 2024-10-16 10:04:00 346.4877          470.7329                16.83673
# 6 2024-10-16 10:05:00 346.4879          470.6089                16.67023
#   Radiation.Level..μSv.h. Turbine.Speed..RPM. Pump.Status Power.Output..MW.
# 1 0.3528194               3301.404            ON           978.5183
# 2 0.3842672               3188.521            ON           934.9445
# 3 1.2149436               2920.910            ON           978.5510
# 4 0.6002048               3058.418            ON          1048.2385
# 5 0.8346390               3147.451            OFF         1064.9994
# ...

# %%
tail(df)
# Out:
#      Timestamp           Reactor.Temp...C. Coolant.Flow.Rate..L.s.
# 1195 2024-10-17 05:54:00 326.1051          468.7484
# 1196 2024-10-17 05:55:00 356.6071          448.2553
# 1197 2024-10-17 05:56:00 349.7054          456.1721
# 1198 2024-10-17 05:57:00 358.2873          454.9406
# 1199 2024-10-17 05:58:00 353.3587          473.1090
# 1200 2024-10-17 05:59:00 370.4621          471.0402
#      Pressure..MPa. Radiation.Level..μSv.h. Turbine.Speed..RPM. Pump.Status
# 1195 16.62962        0.55496491             3372.706            ON
# 1196 16.57322        0.22079815             3234.294            OFF
# 1197 15.51331        0.74585544             3430.530            ON
# 1198 16.50357        0.01518847             2956.519            OFF
# 1199 16.16807       -0.01510724             3293.590            ON
# 1200 15.88626        0.82175415             2965.944            ON
#      Power.Output..MW. Control.Rod.Position.... Steam.Flow.Rate..kg.s.
# ...

# %%
str(df)
# Out:
# 'data.frame':	1200 obs. of  13 variables:
#  $ Timestamp               : chr  "2024-10-16 10:00:00" "2024-10-16 10:01:00" "2024-10-16 10:02:00" "2024-10-16 10:03:00" ...
#  $ Reactor.Temp...C.       : num  357 348 360 373 346 ...
#  $ Coolant.Flow.Rate..L.s. : num  472 464 472 478 471 ...
#  $ Pressure..MPa.          : num  15.6 16.1 15.7 15.9 16.8 ...
#  $ Radiation.Level..μSv.h. : num  0.353 0.384 1.215 0.6 0.835 ...
#  $ Turbine.Speed..RPM.     : num  3301 3189 2921 3058 3147 ...
#  $ Pump.Status             : chr  "ON" "ON" "ON" "ON" ...
#  $ Power.Output..MW.       : num  979 935 979 1048 1065 ...
#  $ Control.Rod.Position....: num  61.9 71.7 66.8 66.3 62.8 ...
#  $ Steam.Flow.Rate..kg.s.  : num  220 220 206 221 241 ...
#  $ Vibration.Level..mm.s.  : num  1.09 2.93 1.3 2.09 2.03 ...
#  $ Water.Level..m.         : num  5.08 5.21 5.2 5.19 5.19 ...
#  $ Anomaly.Detected        : chr  "No" "No" "Yes" "No" ...

# %%
names(df)
# Out:
#  [1] "Timestamp"                "Reactor.Temp...C."
#  [3] "Coolant.Flow.Rate..L.s."  "Pressure..MPa."
#  [5] "Radiation.Level..μSv.h."  "Turbine.Speed..RPM."
#  [7] "Pump.Status"              "Power.Output..MW."
#  [9] "Control.Rod.Position...." "Steam.Flow.Rate..kg.s."
# [11] "Vibration.Level..mm.s."   "Water.Level..m."
# [13] "Anomaly.Detected"

# %%
colnames(df)
# Out:
#  [1] "Timestamp"                "Reactor.Temp...C."
#  [3] "Coolant.Flow.Rate..L.s."  "Pressure..MPa."
#  [5] "Radiation.Level..μSv.h."  "Turbine.Speed..RPM."
#  [7] "Pump.Status"              "Power.Output..MW."
#  [9] "Control.Rod.Position...." "Steam.Flow.Rate..kg.s."
# [11] "Vibration.Level..mm.s."   "Water.Level..m."
# [13] "Anomaly.Detected"

# %%
df$`Radiation.Level..μSv.h.`
# Out:
#    [1]  0.352819354  0.384267165  1.214943629  0.600204846  0.834639000
#    [6]  0.362730185  0.366044116  0.924595443  0.195127137  0.475435870
#   [11]  0.610208223  0.633411781  0.546272014  0.718745934  0.807856727
#   [16]  0.820391264  0.304258857  0.514753471  0.958428859  0.868394156
#   [21]  0.188142165  0.705443970  0.006532425  0.614080471  1.169330105
#   [26]  0.315632185  0.349703086  0.829208934  0.137159545  0.410173491
#   [31]  0.778932341  0.409714246  0.529209004  0.823255713  0.726463825
#   [36]  0.680045519  0.498263316  0.711018335  0.562880196  0.737341683
#   [41]  0.450920392  0.545229308  0.303012662  0.589497717  0.356699741
#   [46]  0.265786065  0.677598344  0.663821933  0.834862120  0.470662329
#   [51]  0.722415854  0.765239272  0.733432142  0.352303895  0.644809045
#   [56]  0.709242089  0.602153540 -0.025943298  0.648146887  1.263759312
#   [61]  0.491988219  0.381576871  0.712004568  0.693713463  0.957820550
# ...

# %%
df$Anomaly.Detected
# Out:
#    [1] "No"  "No"  "Yes" "No"  "No"  "No"  "No"  "No"  "No"  "No"  "No"  "No"
#   [13] "No"  "No"  "No"  "No"  "No"  "No"  "No"  "No"  "No"  "No"  "No"  "No"
#   [25] "No"  "No"  "No"  "No"  "No"  "No"  "No"  "No"  "No"  "No"  "No"  "No"
#   [37] "No"  "No"  "No"  "No"  "No"  "Yes" "No"  "No"  "No"  "No"  "No"  "No"
#   [49] "No"  "No"  "No"  "No"  "No"  "No"  "No"  "No"  "No"  "No"  "No"  "No"
#   [61] "No"  "No"  "No"  "No"  "No"  "No"  "No"  "No"  "No"  "No"  "No"  "No"
#   [73] "Yes" "No"  "Yes" "No"  "No"  "No"  "No"  "No"  "No"  "No"  "No"  "No"
#   [85] "No"  "No"  "No"  "No"  "No"  "No"  "No"  "No"  "No"  "No"  "No"  "No"
#   [97] "No"  "No"  "No"  "No"  "No"  "No"  "No"  "No"  "No"  "No"  "No"  "No"
#  [109] "No"  "No"  "No"  "No"  "No"  "No"  "No"  "Yes" "No"  "No"  "No"  "No"
#  [121] "No"  "No"  "No"  "No"  "No"  "No"  "No"  "No"  "No"  "No"  "No"  "No"
#  [133] "Yes" "No"  "No"  "No"  "No"  "No"  "No"  "Yes" "No"  "No"  "No"  "No"
# ...

# %%
df$Control.Rod.Position....
# Out:
#    [1] 61.91414 71.73156 66.84976 66.32919 62.76751 67.67462 75.42250 69.87406
#    [9] 73.13840 78.32321 71.31878 67.20600 72.33626 67.27852 67.47789 62.40054
#   [17] 74.63129 68.06999 70.91049 64.82019 72.17974 66.19029 69.29146 74.38913
#   [25] 73.95380 69.88985 61.15934 84.96405 78.72929 73.61337 66.23398 69.43204
#   [33] 67.28290 76.31928 71.31251 66.07918 67.64622 75.60594 78.00049 77.64166
#   [41] 73.78516 68.73688 53.79243 71.48580 69.99086 70.69991 70.26949 63.36869
#   [49] 72.78704 73.16108 73.41169 74.73289 73.02026 67.94985 69.64582 70.45562
#   [57] 70.53850 74.99109 73.21834 80.38672 81.03234 70.39825 50.81672 76.18416
#   [65] 67.29812 65.99258 68.00777 67.76678 73.06135 62.20282 64.61140 71.71579
#   [73] 73.11472 73.20771 66.06482 65.10867 67.46683 71.19936 77.42739 59.76281
#   [81] 68.89636 63.33661 61.73879 74.83478 72.72312 72.24717 74.60513 67.60141
#   [89] 67.83681 80.92865 68.76714 73.67566 70.03191 60.75871 59.77685 67.10508
# ...

# %%
al<-df$`Radiation.Level..μSv.h.`
boxplot(al)
# Out:
# plot without title

# %%
cr<-df$Control.Rod.Position....

# %%
boxplot(cr)
# Out:
# plot without title

# %%
cf<-df$Coolant.Flow.Rate..L.s.

# %%
boxplot(cf)
# Out:
# plot without title

# %%
pw<-df$Power.Output..MW.

# %%
png("boxplot_pw.png")
boxplot(pw,main="Power Output")

# %%
hist(df$Water.Level..m.,main="Water Level",ylab = "Frequency",xlab="Water Level",col="red",border="green")
# Out:
# Plot with title “Water Level”

# %%
jpeg("Water_level.jpeg")
hist(df$Water.Level..m.,main="Water Level",ylab = "Frequency",xlab="Water Level",col="red",border="green")
dev.off()
# Out:
# agg_record_1f6886b8e
#                    2
